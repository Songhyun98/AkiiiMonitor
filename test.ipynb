# %%
export NAVER_CLIENT_ID="EGs26hVdRpcDBQxdTT80"

export NAVER_CLIENT_SECRET="EungL3NP4G"

# %%
import os
print(os.getenv("NAVER_CLIENT_ID"))
# Out:
# None

# %%
import pandas as pd

# %%
mb.shape
# Out:
# (300, 7)

# %%
mt = pd.read_parquet(r"D:\Desktop\AkiiiMonitor\data\raw\mention_total\mention_total_20260604.parquet")
mt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   keyword       3 non-null      object
#  1   blog_total    3 non-null      int64
#  2   news_total    3 non-null      int64
#  3   cafe_total    3 non-null      int64
#  4   collected_at  3 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 252.0+ bytes

# %%
mt.head(3)
# Out:
#   keyword  blog_total  news_total  cafe_total                collected_at
# 0   아키클래식       13118        4398        7165  2026-06-04T11:20:17.437552
# 1    포즈간츠        1702         238         527  2026-06-04T11:20:17.437552
# 2   23.65        7046        2738        4019  2026-06-04T11:20:17.437552

# %%
mc = pd.read_parquet(r"D:\Desktop\AkiiiMonitor\data\raw\mention_cafe\mention_cafe_20260604.parquet")
mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2527 entries, 0 to 2526
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   keyword       2527 non-null   object
#  1   title         2527 non-null   object
#  2   description   2527 non-null   object
#  3   cafename      2527 non-null   object
#  4   cafeurl       2527 non-null   object
#  5   link          2527 non-null   object
#  6   collected_at  2527 non-null   object
# dtypes: object(7)
# memory usage: 138.3+ KB

# %%
mc.head(3)
# Out:
#   keyword                                           title  \
# 0   아키클래식  <b>아키클래식</b> 아치-핏 폼 플립플랍 <b>아키클래식</b> 여성 신발 후기
# 1   아키클래식             <b>아키클래식</b> 부메랑 키높이 운동화 230사이즈 새제품
# 2   아키클래식                                         운동화 245
#
#                                          description cafename  \
# 0  <b>아키클래식</b> 아치-핏 폼 플립플랍 <b>아키클래식</b> 여성 신발 후기...    작가모임♡
# 1  7 장 이미지 더보기 〉 상품 정보 <b>아키클래식</b> 부메랑 키높이 운동화 2...     중고나라
# 2  상세 <b>아키클래식</b> 등산화/트레킹화입니다. 신상이라 디자인도 너무 예쁘고,...     중고나라
#
#                               cafeurl  \
# 0   https://cafe.naver.com/gjsdlf1234
# 1  https://cafe.naver.com/joonggonara
# 2  https://cafe.naver.com/joonggonara
#
#                                            link                collected_at
# 0          http://cafe.naver.com/gjsdlf1234/770  2026-06-04T11:20:17.437552
# 1  http://cafe.naver.com/joonggonara/1130264252  2026-06-04T11:20:17.437552
# 2  http://cafe.naver.com/joonggonara/1130261765  2026-06-04T11:20:17.437552

# %%
mn = pd.read_parquet(r"D:\Desktop\AkiiiMonitor\data\raw\mention_news\mention_news_20260604.parquet")
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   keyword       2238 non-null   object
#  1   title         2238 non-null   object
#  2   description   2238 non-null   object
#  3   originallink  2238 non-null   object
#  4   pub_date      2238 non-null   object
#  5   link          2238 non-null   object
#  6   collected_at  2238 non-null   object
# dtypes: object(7)
# memory usage: 122.5+ KB

# %%
mn.head(2)
# Out:
#   keyword                          title  \
# 0   아키클래식  <b>아키클래식</b>, '썸머 블랙프라이데이’ 진행
# 1   아키클래식   <b>아키클래식</b>, 중국 ‘티몰 글로벌’ 입점
#
#                                          description  \
# 0  올위메이크이즈(대표 남수안)의 라이프스타일 스포츠 브랜드 ‘<b>아키클래식</b>’...
# 1  올위메이크이즈(대표 남수안)의 라이프스타일 스포츠 브랜드 ‘<b>아키클래식</b>’...
#
#                                         originallink  \
# 0  http://www.apparelnews.co.kr/news/news_view/?i...
# 1  http://www.apparelnews.co.kr/news/news_view/?i...
#
#                           pub_date  \
# 0  Thu, 04 Jun 2026 09:38:00 +0900
# 1  Wed, 20 May 2026 14:28:00 +0900
#
#                                                 link  \
# 0  http://www.apparelnews.co.kr/news/news_view/?i...
# 1  http://www.apparelnews.co.kr/news/news_view/?i...
#
#                  collected_at
# 0  2026-06-04T11:20:17.437552
# 1  2026-06-04T11:20:17.437552

# %%
mb = pd.read_parquet(r"D:\Desktop\AkiiiMonitor\data\raw\mention_blog\mention_blog_20260604.parquet")
mb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   keyword       3000 non-null   object
#  1   title         3000 non-null   object
#  2   description   3000 non-null   object
#  3   bloggername   3000 non-null   object
#  4   postdate      3000 non-null   object
#  5   link          3000 non-null   object
#  6   collected_at  3000 non-null   object
# dtypes: object(7)
# memory usage: 164.2+ KB

# %%
mb.head(2)
# Out:
#   keyword                                          title  \
# 0   아키클래식             <b>아키클래식</b> 프리워크 발 편한 운동화 직접 신어보니
# 1   아키클래식  [<b>아키클래식</b>] 발 편한 운동화 프리워크 두개 구매시 자동 추가...
#
#                                          description       bloggername  \
# 0  <b>아키클래식</b> 프리워크 발 편한 운동화 직접 신어보니 <b>아키클래식</b...  hnded60979님의 블로그
# 1  [<b>아키클래식</b>] 발 편한 운동화 프리워크 두개 구매시 자동 추가 할인 [...   tqil71666님의 블로그
#
#    postdate                                            link  \
# 0  20260604  https://blog.naver.com/hnded60979/224305503816
# 1  20260604   https://blog.naver.com/tqil71666/224305501518
#
#                  collected_at
# 0  2026-06-04T11:20:17.437552
# 1  2026-06-04T11:20:17.437552

# %%
mb[mb['keyword'] == '아키클래식'].tail(10)
# Out:
#     keyword                                         title  \
# 990   아키클래식                        발 편한 운동화, 합리적 가격으로 만나기
# 991   아키클래식          발 편안함을 선사하는 <b>아키클래식</b> 범퍼 트레이너의 매력
# 992   아키클래식  <b>아키클래식</b> 발 편한 운동화 범퍼 트레이너 2개 구매 시 자동...
# 993   아키클래식          발 편안함과 디자인을 동시에, <b>아키클래식</b> 운동화 리뷰
# 994   아키클래식       <b>아키클래식</b> 발 편한 운동화, 2개 구매 시 추가 할인 정보
# 995   아키클래식                    나이키 운동화 선택 시 고려할 3가지 필수 기능
# 996   아키클래식               나이키 운동화, 스타일과 편안함을 모두 갖춘 완벽한 선택
# 997   아키클래식      89,000원 가격대, <b>아키클래식</b> 운동화의 성능과 효율 분석
# 998   아키클래식           발 편한 나이키 운동화, <b>아키클래식</b> 신상 비교 분석
# 999   아키클래식     남녀 공용, 키높이와 충격흡수까지 <b>아키클래식</b> 운동화 효율 분석
#
#                                            description         bloggername  \
# 990  브랜드: <b>아키클래식</b> 운동화를 고를 때 보면 기준이 사람마다 꽤 달라요....  bncsomewhere님의 블로그
# 991  <b>아키클래식</b>의 발 편한 운동화인 범퍼 트레이너는 이러한 요구를 충족시키기...              고구마연구소
# 992  아래 링크 참고 두개구매추가할인확인하기 확인하기 <b>아키클래식</b> 발 편한 운...  unemployed8q님의 블로그
# ...

# %%
nd = pd.read_parquet(r"D:\Desktop\AkiiiMonitor\data\raw\naver_datalab\naver_datalab_20260604.parquet")
nd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   period         1800 non-null   object
#  1   keyword_group  1800 non-null   object
#  2   axis           1800 non-null   object
#  3   ratio          1800 non-null   float64
#  4   collected_at   1800 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 70.4+ KB

# %%
nd.head(3)
# Out:
#        period keyword_group    axis     ratio                collected_at
# 0  2022-12-26         아키클래식  direct  44.68168  2026-06-04T11:20:15.858549
# 1  2023-01-02         아키클래식  direct  41.35908  2026-06-04T11:20:15.858549
# 2  2023-01-09         아키클래식  direct  39.62088  2026-06-04T11:20:15.858549

# %%
ns = pd.read_parquet(r"D:\Desktop\AkiiiMonitor\data\raw\naver_shopping\naver_shopping_20260604.parquet")
ns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2055 entries, 0 to 2054
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   period        2055 non-null   object
#  1   keyword       2055 non-null   object
#  2   gender        2055 non-null   object
#  3   age           2055 non-null   object
#  4   ratio         2055 non-null   float64
#  5   collected_at  2055 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 96.5+ KB

# %%
ns.head(3)
# Out:
#        period keyword gender  age     ratio                collected_at
# 0  2022-12-26   아키클래식    all  all  71.35896  2026-06-04T11:20:30.873539
# 1  2023-01-02   아키클래식    all  all  63.77910  2026-06-04T11:20:30.873539
# 2  2023-01-09   아키클래식    all  all  55.87439  2026-06-04T11:20:30.873539

# %%
from collectors.naver_shopping import NaverShoppingCollector
import json

collector = NaverShoppingCollector(
        client_id="EGs26hVdRpcDBQxdTT80",
        client_secret="5PIziAaWiC",
    )

raw = collector.fetch_keyword_trend(
    category="50000167",
    keywords=[{"name": "아키클래식", "param": ["아키클래식"]}],
    gender="f",
    time_unit="week",
)
print(json.dumps(raw, ensure_ascii=False, indent=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       2 import json
#       4 collector = NaverShoppingCollector(
#       5         client_id="EGs26hVdRpcDBQxdTT80",
#       6         client_secret="5PIziAaWiC",
#       7     )
# ----> 9 raw = collector.fetch_keyword_trend(
#      10     category="50000167",
#      11     keywords=[{"name": "아키클래식", "param": ["아키클래식"]}],
#      12     gender="f",
#      13     time_unit="week",
#      14 )
#      15 print(json.dumps(raw, ensure_ascii=False, indent=2))
#
# TypeError: NaverShoppingCollector.fetch_keyword_trend() got an unexpected keyword argument 'keywords'. Did you mean 'keyword'?

# %%
# param 여러 개 테스트
response = requests.post(
    "https://openapi.naver.com/v1/datalab/shopping/category/keywords",
    headers=headers,
    data=json.dumps({
        "startDate": "2023-01-01",
        "endDate": "2026-06-03",
        "timeUnit": "week",
        "category": "50000167",
        "keyword": [
            {"name": "여행시그널", "param": ["여행 운동화", "여행운동화", "여행용 운동화"]},
        ],
        "device": "",
        "gender": "",
        "ages": []
    }, ensure_ascii=False).encode('utf-8')
)
print(response.status_code)
print(json.dumps(response.json(), ensure_ascii=False, indent=2))
# Out:
# 400
# {
#   "errMsg": "TypeError: .keyword[0].param -> should NOT have more than 1 items",
#   "errId": "2026-06-03T13:54:04+09:00/479326731-879639852",
#   "body": "{\"startDate\":\"2023-01-01\",\"endDate\":\"2026-06-03\",\"timeUnit\":\"week\",\"category\":\"50000167\",\"keyword\":[{\"name\":\"여행시그널\",\"param\":[\"여행 운동화\",\"여행운동화\",\"여행용 운동화\"]}],\"device\":\"\",\"gender\":\"\",\"ages\":[]}"
# }

# %%
response = requests.post(
    "https://openapi.naver.com/v1/datalab/shopping/category/keywords",
    headers=headers,
    data=json.dumps({
        "startDate": "2023-01-01",
        "endDate": "2026-06-03",
        "timeUnit": "week",
        "category": "50000167",
        "keyword": [
            {"name": "여행시그널", "param": ["여행 운동화"]},
            {"name": "발건강시그널", "param": ["족저근막염"]},
        ],
        "device": "",
        "gender": "",
        "ages": []
    }, ensure_ascii=False).encode('utf-8')
)
print(response.status_code)
print(json.dumps(response.json(), ensure_ascii=False, indent=2))
# Out:
# 200
# {
#   "startDate": "2022-12-26",
#   "endDate": "2026-06-03",
#   "timeUnit": "week",
#   "results": [
#     {
#       "title": "여행시그널",
#       "keyword": [
#         "여행운동화"
#       ],
#       "data": [
#         {
#           "period": "2023-12-11",
#           "ratio": 100
#         }
#       ]
#     },
#     {
#       "title": "발건강시그널",
#       "keyword": [
#         "족저근막염"
#       ],
#       "data": [
#         {
#           "period": "2024-12-02",
#           "ratio": 100
#         }
#       ]
#     }
#   ]
# }

# %%
import requests
import json

headers = {
    "X-Naver-Client-Id": "EGs26hVdRpcDBQxdTT80",
    "X-Naver-Client-Secret": "5PIziAaWiC",
    "Content-Type": "application/json",
}

# market 그룹 4개 한번에 테스트
response = requests.post(
    "https://openapi.naver.com/v1/datalab/shopping/category/keywords",
    headers=headers,
    json={
        "startDate": "2023-01-01",
        "endDate": "2026-06-03",
        "timeUnit": "week",
        "category": "50000167",
        "keyword": [
            {"name": "아키클래식", "param": ["아키클래식", "AKIII", "AKIII CLASSIC", "아키 클래식"]},
            {"name": "컴포트수요지수", "param": ["편한 운동화", "발 편한 신발", "편한 신발", "컴포트화", "워킹화", "경량 운동화"]},
            {"name": "여행시그널", "param": ["여행 운동화", "여행운동화", "여행용 운동화", "트레킹화", "트래킹화"]},
            {"name": "발건강시그널", "param": ["족저근막염 운동화", "족저근막 운동화", "족저근막염 신발", "아치서포트", "발건강 운동화", "발 건강 신발"]},
        ],
        "device": "",
        "gender": "",
        "ages": []
    }
)

print(response.status_code)
print(json.dumps(response.json(), ensure_ascii=False, indent=2))
# Out:
# 400
# {
#   "errMsg": "TypeError: .keyword[0].param -> should NOT have more than 1 items",
#   "errId": "2026-06-03T11:10:14+09:00/896224660-134994346",
#   "body": "{\"startDate\":\"2023-01-01\",\"endDate\":\"2026-06-03\",\"timeUnit\":\"week\",\"category\":\"50000167\",\"keyword\":[{\"name\":\"아키클래식\",\"param\":[\"아키클래식\",\"AKIII\",\"AKIII CLASSIC\",\"아키 클래식\"]},{\"name\":\"컴포트수요지수\",\"param\":[\"편한 운동화\",\"발 편한 신발\",\"편한 신발\",\"컴포트화\",\"워킹화\",\"경량 운동화\"]},{\"name\":\"여행시그널\",\"param\":[\"여행 운동화\",\"여행운동화\",\"여행용 운동화\",\"트레킹화\",\"트래킹화\"]},{\"name\":\"발건강시그널\",\"param\":[\"족저근막염 운동화\",\"족저근막 운동화\",\"족저근막염 신발\",\"아치서포트\",\"발건강 운동화\",\"발 건강 신발\"]}],\"device\":\"\",\"gender\":\"\",\"ages\":[]}"
# }

# %%
import json
import requests

headers = {
    "X-Naver-Client-Id": "EGs26hVdRpcDBQxdTT80",
    "X-Naver-Client-Secret": "EungL3NP4G",
    "Content-Type": "application/json",
}

# 카테고리 없이 버켄스탁만 조회
response = requests.post(
    "https://openapi.naver.com/v1/datalab/shopping/category/keywords",
    headers=headers,
    json={
        "startDate": "2025-06-01",
        "endDate": "2026-06-01",
        "timeUnit": "week",
        "category": "50000000",  # 패션의류 상위 카테고리
        "keyword": [
            {"name": "버켄스탁", "param": ["버켄스탁"]},
            {"name": "크록스", "param": ["크록스"]},
        ],
        "device": "",
        "gender": "",
        "ages": []
    }
)
print(json.dumps(response.json(), ensure_ascii=False, indent=2))
# Out:
# {
#   "errorMessage": "NID AUTH Result Invalid (28) : Authentication failed. (인증에 실패했습니다.)",
#   "errorCode": "024"
# }

# %%
from pytrends.request import TrendReq
import json

pytrends = TrendReq(hl='ko', tz=540)  # 한국 시간대

pytrends.build_payload(
    kw_list=["아키클래식", "버켄스탁", "크록스"],
    timeframe="today 12-m",  # 최근 1년
    geo="KR"  # 한국
)

df = pytrends.interest_over_time()
print(df)
# Out:
#             아키클래식  버켄스탁  크록스  isPartial
# date
# 2025-06-01      0    16   69      False
# 2025-06-08      0    15   82      False
# 2025-06-15      0    14   85      False
# 2025-06-22      3    16   79      False
# 2025-06-29      0    10   79      False
# 2025-07-06      4    13  100      False
# 2025-07-13      0    13   99      False
# 2025-07-20      4    13   92      False
# 2025-07-27      0    10   95      False
# 2025-08-03      0    12   84      False
# 2025-08-10      0    12   66      False
# 2025-08-17      4     6   65      False
# 2025-08-24      0     8   64      False
# 2025-08-31      0     6   59      False
# 2025-09-07      0     8   51      False
# 2025-09-14      0     9   48      False
# 2025-09-21      3     9   52      False
# 2025-09-28      5    10   41      False
# 2025-10-05      0     6   43      False
# 2025-10-12      0     7   48      False
# 2025-10-19      0     6   48      False
# 2025-10-26      5     6   40      False
# ...

# %%
import os
import pandas as pd
from naver_datalab import NaverDataLabCollector

collector = NaverDataLabCollector(
    client_id="EGs26hVdRpcDBQxdTT80",
    client_secret="EungL3NP4G",
)

raw = collector.fetch_archi_vs_market()
rows = collector.parse_to_rows(raw)

df = pd.DataFrame(rows)
df["period"] = pd.to_datetime(df["period"])
df = df.sort_values("period")

df
# Out:
#         period keyword_group     ratio                collected_at
# 0   2025-06-02         아키클래식   5.94992  2026-06-02T10:42:40.951255
# 53  2025-06-02        컴포트화시장   3.38120  2026-06-02T10:42:40.951255
# 106 2025-06-02         경쟁브랜드  86.76186  2026-06-02T10:42:40.951255
# 1   2025-06-09         아키클래식   6.00544  2026-06-02T10:42:40.951255
# 54  2025-06-09        컴포트화시장   3.61476  2026-06-02T10:42:40.951255
# ..         ...           ...       ...                         ...
# 51  2026-05-25         아키클래식   4.96930  2026-06-02T10:42:40.951255
# 104 2026-05-25        컴포트화시장   3.08539  2026-06-02T10:42:40.951255
# 105 2026-06-01        컴포트화시장   0.48654  2026-06-02T10:42:40.951255
# 52  2026-06-01         아키클래식   0.75063  2026-06-02T10:42:40.951255
# 158 2026-06-01         경쟁브랜드  11.39348  2026-06-02T10:42:40.951255
#
# [159 rows x 4 columns]

# %%
import sys
sys.path.append(r"D:\Desktop\AkiiiMonitor\collectors")

import json
import requests
from naver_search import NaverSearchCollector

collector = NaverSearchCollector(
    client_id="EGs26hVdRpcDBQxdTT80",
    client_secret="5PIziAaWiC",
)

URLS = {
    "블로그": "https://openapi.naver.com/v1/search/blog.json",
    "뉴스":   "https://openapi.naver.com/v1/search/news.json",
    "카페":   "https://openapi.naver.com/v1/search/cafearticle.json",
}

for name, url in URLS.items():
    response = requests.get(
        url,
        headers=collector.headers,
        params={"query": '"아키클래식"', "display": 3, "sort": "date"}
    )
    print(f"\n{'='*20} {name} {'='*20}")
    print(json.dumps(response.json(), ensure_ascii=False, indent=2))
# Out:
# ==================== 블로그 ====================
# {
#   "lastBuildDate": "Thu, 04 Jun 2026 10:47:48 +0900",
#   "total": 13117,
#   "start": 1,
#   "display": 3,
#   "items": [
#     {
#       "title": "<b>아키클래식</b> 성수점 썸머 블랙프라이데이 프로모션 안내",
#       "link": "https://blog.naver.com/akiiiclassic_seongsu/224304646334",
#       "description": "2026.06.04 ~ 2026.06.18 &lt; 2026 SUMMER BLACK FRIDAY &gt; &lt; 썸머 블랙프라이데이 쿠폰 &gt; - 7만원 이상 구매 시 15,000원 할인 - 12만원 이상 구매 시 25,000원 할인 - 15만원 이상 구매 시 30,000원 할인 - 20만원... ",
#       "bloggername": "아키클래식 성수점",
#       "bloggerlink": "blog.naver.com/akiiiclassic_seongsu",
#       "postdate": "20260604"
#     },
#     {
#       "title": "데일리 아이템 방한부츠 아미뉴 남성 초경량 방한 부츠 털... ",
#       "link": "https://blog.naver.com/gp6ffzmco47/224305437439",
#       "description": "<b>아키클래식</b> 여성용 에스텔라 리커버리 패딩 부츠 AKAOWWH01 고객들 사이에서 입증된 만족도와 인기 다른... 4.<b>아키클래식</b> 여성용 에스텔라 리커버리 패딩 부츠 AKAOWWH01 ￦ 71,900원 별점 : ⭐⭐⭐⭐⭐ 5. 자카르타... ",
# ...

# %%
KEYWORDS = ["아키클래식", "포즈간츠", "23.65"]

URLS = {
    "블로그": "https://openapi.naver.com/v1/search/blog.json",
    "뉴스":   "https://openapi.naver.com/v1/search/news.json",
    "카페":   "https://openapi.naver.com/v1/search/cafearticle.json",
}

for name, url in URLS.items():
    print(f"\n{'='*20} {name} {'='*20}")
    response = requests.get(
        url,
        headers=collector.headers,
        params={"query": '"아키클래식"', "display": 2, "sort": "date"}
    )
    print(json.dumps(response.json(), ensure_ascii=False, indent=2))
# Out:
# ==================== 블로그 ====================
# {
#   "lastBuildDate": "Thu, 04 Jun 2026 10:47:53 +0900",
#   "total": 13117,
#   "start": 1,
#   "display": 2,
#   "items": [
#     {
#       "title": "<b>아키클래식</b> 성수점 썸머 블랙프라이데이 프로모션 안내",
#       "link": "https://blog.naver.com/akiiiclassic_seongsu/224304646334",
#       "description": "2026.06.04 ~ 2026.06.18 &lt; 2026 SUMMER BLACK FRIDAY &gt; &lt; 썸머 블랙프라이데이 쿠폰 &gt; - 7만원 이상 구매 시 15,000원 할인 - 12만원 이상 구매 시 25,000원 할인 - 15만원 이상 구매 시 30,000원 할인 - 20만원... ",
#       "bloggername": "아키클래식 성수점",
#       "bloggerlink": "blog.naver.com/akiiiclassic_seongsu",
#       "postdate": "20260604"
#     },
#     {
#       "title": "데일리 아이템 방한부츠 아미뉴 남성 초경량 방한 부츠 털... ",
#       "link": "https://blog.naver.com/gp6ffzmco47/224305437439",
#       "description": "<b>아키클래식</b> 여성용 에스텔라 리커버리 패딩 부츠 AKAOWWH01 고객들 사이에서 입증된 만족도와 인기 다른... 4.<b>아키클래식</b> 여성용 에스텔라 리커버리 패딩 부츠 AKAOWWH01 ￦ 71,900원 별점 : ⭐⭐⭐⭐⭐ 5. 자카르타... ",
# ...
